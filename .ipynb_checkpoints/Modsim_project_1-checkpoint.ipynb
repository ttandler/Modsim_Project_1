# %% [markdown]
# # ModSim Project 1: Quantifying the Effect of the Great Depression

# %%
# Configure Jupyter so figures appear in the notebook
# %matplotlib inline

# Configure Jupyter to display the assigned value after an assignment
# %config InteractiveShell.ast_node_interactivity='last_expr_or_assign'

# import functions from the modsim.py module
from modsim import *

#from pandas import read_html

import pandas as pd

# %%
data = pd.read_csv("US_population.csv",index_col ='year')
pop = data.population /1e6;

# %%
plot (pop,':', label ='US Population (Data)')
decorate(xlabel='Year',
        ylabel='US Population (million)')
savefig('proj01-fig0.png')
# Out:
# Saving figure to file proj01-fig0.png

# %% [markdown]
# ## What would the population of the United States be in 2016 if the Great Depression hadn't happened?
#
# From 1929-1939, the United States experienced a period of economic depression called The Great Depression. During this time, unemployment rose to 25%, crop prices dropped about 60%, and many individuals became homeless. The poor conditions were only made worse by the Dust Bowl during the 1930s. Due to damaged agricultural lands, it can be assumed crops decreased in quality and quantity, limiting their availability. Furthermore, due to harsh economic conditions, families had less money to spend on fresh produce. Given the summation of these conditions, we hypothesize that fewer families than normally expected would aim to have large families. The many number of children would be difficult to feed. Additionally, with both females and males, we would expect fertility and pregnancy success rates to decrease.
#
# Therefore, for our MODSIM project, we are interested in determining what the population of the United States would have been in 2016, had the Great Depression not have happened. This would be interesting because we think that due to the harsh conditions, fertility and the population of the United States, did not increase as it would have been on trend to do.

# %% [markdown]
# ### Methodology
# In order to do this, we will first:
# 1. Decide what the relevant period is, i.e., when do we think the Great Depression starts affecting growth rate and when does it stop?
# 2. Calculate the growth rate before the Great Depression.
# 3. Apply this growth rate through the Great Depression (pretend that the Great Depression didn't happen).
# 4. Calculate the growth rate after the Great Depression.
# 5. Apply the growth after the Great Depression.
# 6. Record the projected population in 2016 if the Great Depression hadn't happened.

# %% [markdown]
# **First, we defined the period encompassing the Great Depression.**
#
# Historians define the start of the Great Depression with the crash of the stock market in 1929, which is why we defined the start year of the Great Depression as 1929. According to the Foundation for Economic Education, the effects of the Great Depression, like unemployment, poverty, etc., were alleviated starting in 1941, which is why we defined the end year of the Great Depression as 1941.
#
# We defined the start of the period after the Great Depression as the year after the end of the Great Depression.

# %%
t_0 = get_first_label(pop)
t_gd_start = 1929
t_gd_end = 1941
t_agd_start = t_gd_end + 1
t_end = get_last_label(pop)
# Out:
# 2016

# %% [markdown]
# **Then, we calculated the growth rate before the Great Depression.**
#
# In order to do this, we first had to check whether the populations preceding the Great Depression were linear or nonlinear. We checked this by selecting out the relevant subset of the data and plotting the populations. The section preceding the Great Depression seemed linear enough that a linear growth model seemed appropriate.

# %%
pop_pre_gd = pop [(pop.index >= t_0) & (pop.index <= t_gd_start -1)];

# %%
plot (pop_pre_gd, '-', label = "US Population Before the Great Depression (Data)")
decorate(xlabel='Year',
        ylabel='US Population (million)')
savefig('proj01-fig01.png')
# Out:
# Saving figure to file proj01-fig01.png

# %% [markdown]
# Then we used the linear growth model to calculate the growth rate before the Great Depression.

# %%
# Find the change in time
elapsed_time_bgd = t_gd_start - t_0

# Find the change in population
p_0 =  pop[t_0]
p_gd_start = pop[t_gd_start]
deltap_bgd = p_gd_start - p_0

# Calculate the growth rate (change in population/change in time)
growth_rate_bgd = deltap_bgd/elapsed_time_bgd
# Out:
# 1.5749310344827587

# %% [markdown]
# **Then we calculated the growth rate after the Great Depression.**
#
# We followed a similar procedure, first checking to see if a linear or quadratic growth model would be more appropriate for the section after the Great Depression. The plot suggests that a linear growth model was more appropriate for the time period after the Great Depression.

# %%
pop_agd = pop [(pop.index >= t_agd_start) & (pop.index <= t_end)];

# %%
plot (pop_agd, '-', label = "US Population After the Great Depression (Data)")
decorate(xlabel='Year',
        ylabel='US Population (million)')
savefig('proj01-fig02.png')
# Out:
# Saving figure to file proj01-fig02.png

# %% [markdown]
# Then we used the linear growth model to calculate the growth rate after the Great Depression.

# %%
# Find the change in time
elapsed_time_agd = t_end - t_agd_start

# Find the change in population
p_agd_start = pop[t_agd_start]
p_end = pop[t_end]
deltap_agd = p_end - p_agd_start

# Calculate the growth rate (change in population.change in time)
growth_rate_agd = deltap_agd/elapsed_time_agd
# Out:
# 2.554463527027027

# %% [markdown]
# We created a System object to contain the useful information to describe our model and run the simulation. This included the relevant time periods, populations, and growth rates.

# %%
system = System(t_0 = t_0,
                t_gd_start = t_gd_start,
                t_gd_end = t_gd_end,
                t_agd_start = t_agd_start,
                t_end = t_end,
                p_gd_start = p_gd_start,
                p_agd_start = p_agd_start,
                growth_rate_bgd = growth_rate_bgd,
                growth_rate_agd = growth_rate_agd);

# %% [markdown]
# We created a function to update the population every year from the start of the Great Depression to the end of the dataset. The function checks whether to apply the growth rate before the Great Depression or the growth rate after the Great Depression by checking the year.

# %%
def update_func_gd (pop,t,system):
    if t <= t_gd_end:
        return pop + system.growth_rate_bgd
    else:
        return pop + system.growth_rate_agd

gd_results = run_simulation (system, update_func_gd);

# %% [markdown]
# We then created a function to run the simulation starting from the start of the Great Depression to the end of the dataset.

# %%
def run_simulation (system, update_func):
    results = TimeSeries()
    results[system.t_gd_start] = system.p_gd_start
    
    for t in linrange(system.t_gd_start, system.t_end):
        results[t+1] = update_func(results[t], t, system)
        
    return results

# %% [markdown]
# To plot the model's projections against the data, we combined the data for the US population preceding the Great Depression to the model's projection post-Great-Depression.

# %%
results_thru_gd = pop_pre_gd.append(gd_results);

# %%
plot (results_thru_gd, ':',label = "without GD")
plot(pop, '-', label = "with GD")
decorate(xlabel='Year',
        ylabel='US Population (million)')
savefig('proj01-fig03.png')
# Out:
# Saving figure to file proj01-fig03.png

# %%
# The predicted population of the United States in 2016
results_thru_gd[2016]
# Out:
# 331.2714044482764

# %%
# The actual population of the United States in 2016
pop[2016]
# Out:
# 323.889854

# %% [markdown]
# ## Results
#
# The actual United States population in 2016 was approximately 324M. Based on our model, had the Great Depression not occurred, the experimental population in 2016 would have been 331M.
#
# ## Interpretation
#
# This 2.5% increase in population suggests that the Great Depression did have an impact on population growth rates. Although we cannot claim significance on this value due to not running statistical evaluation, a 2.5% increase is a meaningful data point. With a greater population, the effects of climate change might have been accelerated as there would be more individuals contributing to the greenhouse effect.
#
# Our model does have several limitations:
# 1.	We do not have hard evidence of when the effects of the Great Depression began and when they ended. We assumed the effects were felt starting in 1929 when the economy crashed and ending a few years after the economy was stable again in 1941.
# 2.	We fit a linear model to all three periods surrounding the great depression (before, during, and after). Even though we only had data for 29 years before the Great Depression a linear model seemed to best population growth. The population growth after the Great Depression also was best fit by a linear model rather than a quadratic or other model. Because we had a linear trend both before and after the Great Depression we determined it would make sense also have a linear model during the Great Depression. However, we recognize that without actual data, this trend may or may not be representative of the actual growth during that period.
# 3.	The Great Depression did have effects on fertility rates so additional iterations of our model could include fertility rates as a method of calculating birth rates. If we iterated again, we might have modeled the population based on fertility, birth, and death rates instead of overall growth rate. This would have potential to be a more accurate representation of the population as more evaluation metrics would have been included. Instead, in our model, fertility, birth, and death rates are implicitly included rather than explicitly.
